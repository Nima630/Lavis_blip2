# %%
import torch

ckpt_path = "lavis/output/BLIP2/CAM_FRONT_4_changes/20250722005/checkpoint_best.pth"
ckpt = torch.load(ckpt_path, map_location="cpu")

print("Top-level keys:", ckpt.keys())
print("Model state_dict keys:", list(ckpt['model'].keys())[:10])
# Out:
# Top-level keys: dict_keys(['model', 'optimizer', 'config', 'scaler', 'epoch'])
# Model state_dict keys: []

# %%
import torch

ckpt_path = "lavis/output/BLIP2/CAM_FRONT_4_changes/20250722123/checkpoint_best.pth"
ckpt = torch.load(ckpt_path, map_location="cpu")

print("Top-level keys:", ckpt.keys())
print("Model state_dict keys:", list(ckpt['model'].keys())[:10])
# Out:
# Top-level keys: dict_keys(['model', 'optimizer', 'config', 'scaler', 'epoch'])
# Model state_dict keys: ['query_tokens', 'query_tokens_lidar', 'log_temp', 'temp', 'rgb_input_proj.weight', 'rgb_input_proj.bias', 'lidar_input_proj.weight', 'lidar_input_proj.bias', 'rgb_layernorm.weight', 'rgb_layernorm.bias']

# %%
print("\nFull key count:", len(ckpt['model']))
print("\nSample keys:", list(ckpt['model'].keys())[:20])


print("Qformer keys:", [k for k in ckpt['model'] if "Qformer" in k])
print("vision_proj keys:", [k for k in ckpt['model'] if "vision_proj" in k])
# Out:
# Full key count: 256
#
# Sample keys: ['query_tokens', 'query_tokens_lidar', 'log_temp', 'temp', 'rgb_input_proj.weight', 'rgb_input_proj.bias', 'lidar_input_proj.weight', 'lidar_input_proj.bias', 'rgb_layernorm.weight', 'rgb_layernorm.bias', 'lidar_layernorm.weight', 'lidar_layernorm.bias', 'Qformer.bert.embeddings.position_ids', 'Qformer.bert.embeddings.word_embeddings.weight', 'Qformer.bert.embeddings.position_embeddings.weight', 'Qformer.bert.embeddings.LayerNorm.weight', 'Qformer.bert.embeddings.LayerNorm.bias', 'Qformer.bert.encoder.layer.0.attention.self.query.weight', 'Qformer.bert.encoder.layer.0.attention.self.query.bias', 'Qformer.bert.encoder.layer.0.attention.self.key.weight']
# ...
